# %%
#Shahanaz A H
#18/03/24

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('all')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
#Tokenization using NLTK
from nltk import word_tokenize,sent_tokenize
sent= "Hi I am Shahanaz . I am a student . Iam doing BTech"
print(word_tokenize(sent))
print(sent_tokenize(sent))
# Out:
# ['Hi', 'I', 'am', 'Shahanaz', '.', 'I', 'am', 'a', 'student', '.', 'Iam', 'doing', 'BTech']
# ['Hi I am Shahanaz .', 'I am a student .', 'Iam doing BTech']

# %%
from nltk.tokenize import sent_tokenize
text="Hello everyone. Welcome to KMEA"
sent_tokenize(text)

import nltk.data

tokenizer=nltk.data.load('tokenizers/punkt/PY3/english.pickle')    #loading punktsentencetokenizer using english pickle file
tokenizer.tokenize(text)
# Out:
# ['Hello everyone.', 'Welcome to KMEA']

# %%
from nltk.tokenize import sent_tokenize
textt="എൻ്റെ അമ്മൂമ്മയാണ് വീടിൻ്റെ മുഴുവൻ അമ്മ. അവളുടെ മുഖത്ത് മനോഹരമായ പുഞ്ചിരിയോടെ കുടുംബത്തെ മുഴുവൻ പരിപാലിക്കുന്നത് അവളാണ്."
sent_tokenize(textt)

import nltk.data

tokenizer=nltk.data.load('tokenizers/punkt/PY3/malayalam.pickle')    #loading punktsentencetokenizer using malayalam pickle file
tokenizer.tokenize(textt)
# Out:
# ['എൻ്റെ അമ്മൂമ്മയാണ് വീടിൻ്റെ മുഴുവൻ അമ്മ.',
#  'അവളുടെ മുഖത്ത് മനോഹരമായ പുഞ്ചിരിയോടെ കുടുംബത്തെ മുഴുവൻ പരിപാലിക്കുന്നത് അവളാണ്.']

# %%
from nltk.tokenize import TreebankWordTokenizer
test="This is an example of dummy data ihgu bdhggh nbhsgycg  ncbb"
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(test)
# Out:
# ['This',
#  'is',
#  'an',
#  'example',
#  'of',
#  'dummy',
#  'data',
#  'ihgu',
#  'bdhggh',
#  'nbhsgycg',
#  'ncbb']

# %%
from nltk.stem import PorterStemmer
porter =PorterStemmer()    #create an object of class PorterStemmer
print(porter.stem("play"))
print(porter.stem("playing"))
print(porter.stem("played"))
# Out:
# play
# play
# play

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("playing",'v'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# play

# %%
#pip install pandas
import pandas as pd
df=pd.read_csv('train.csv',header=None)
df.head()
# Out:
#                                                    0      1
# 0                                                sms  label
# 1  Go until jurong point, crazy.. Available only ...      0
# 2                    Ok lar... Joking wif u oni...\n      0
# 3  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 4  U dun say so early hor... U c already then say...      0

# %%
Read_file=open('train.csv').read()
Read_file[0:500]
# Out:
# 'sms,label\n"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...\n",0\n"Ok lar... Joking wif u oni...\n",0\n"Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C\'s apply 08452810075over18\'s\n",1\n"U dun say so early hor... U c already then say...\n",0\n"Nah I don\'t think he goes to usf, he lives around here though\n",0\n"FreeMsg Hey there darling it\'s been 3 week\'s now and n'

# %%
parsed_data=Read_file.replace('\t','\n').split('\n')
parsed_data[0:20]
# Out:
# ['sms,label',
#  '"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  '",0',
#  '"Ok lar... Joking wif u oni...',
#  '",0',
#  '"Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C\'s apply 08452810075over18\'s',
#  '",1',
#  '"U dun say so early hor... U c already then say...',
#  '",0',
#  '"Nah I don\'t think he goes to usf, he lives around here though',
#  '",0',
#  '"FreeMsg Hey there darling it\'s been 3 week\'s now and no word back! I\'d like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv',
#  '",1',
#  '"Even my brother is not like to speak with me. They treat me like aids patent.',
#  '",0',
#  '"As per your request \'Melle Melle (Oru Minnaminunginte Nurungu Vettam)\' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune',
#  '",0',
# ...

# %%
label_list=parsed_data[0::2]
msg_list=parsed_data[1::2]
print(label_list[0:5])
print(msg_list[0:5])
# Out:
# ['sms,label', '",0', '",0', '",1', '",0']
# ['"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', '"Ok lar... Joking wif u oni...', '"Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C\'s apply 08452810075over18\'s', '"U dun say so early hor... U c already then say...', '"Nah I don\'t think he goes to usf, he lives around here though']

# %%
import pandas as pd
dataset=pd.DataFrame({
    'label':label_list[::-1],
    'sms':msg_list})
dataset['label']=dataset['label'].str.replace('"','')
dataset['label']=dataset['label'].str.replace(',','')
dataset.head()
# Out:
#   label                                                sms
# 0     0  "Go until jurong point, crazy.. Available only...
# 1     0                     "Ok lar... Joking wif u oni...
# 2     0  "Free entry in 2 a wkly comp to win FA Cup fin...
# 3     0  "U dun say so early hor... U c already then sa...
# 4     1  "Nah I don't think he goes to usf, he lives ar...

# %%
#shape of the dataset
print(f'Input data has {len(dataset)}rows,{len(dataset.columns)}columns')
# Out:
# Input data has 5575rows,2columns

# %%
print(f'ham={len(dataset[dataset["label"]=="0"])}')
print(f'spam={len(dataset[dataset["label"]=="1"])}')
# Out:
# ham=4827
# spam=747

# %%
import pandas as pd
pd.set_option('display.max_colwidth',100)
data=pd.read_csv('train.csv')
data.columns=['label','msg']
data.head()
# Out:
#                                                                                                  label  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                      Ok lar... Joking wif u oni...\n
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                  U dun say so early hor... U c already then say...\n
# 4                                      Nah I don't think he goes to usf, he lives around here though\n
#
#    msg
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
def remove_punctuation(txt):
  txt_nopunct=[c for c in txt if c in string.punctuation]  #list comprehention is used which means writing loops and if stmt in same single line
  txt_nopunct=" ".join([c for c in txt if c not in string.punctuation])
  return txt_nopunct

# %%
data['msg']=data['msg'].astype(str)

# %%
data['msg_clean']=data['msg'].apply(lambda x:remove_punctuation(x))
data.head()
# Out:
#                                                                                                  label  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                      Ok lar... Joking wif u oni...\n
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                  U dun say so early hor... U c already then say...\n
# 4                                      Nah I don't think he goes to usf, he lives around here though\n
#
#   msg msg_clean
# 0   0         0
# 1   0         0
# 2   1         1
# 3   0         0
# 4   0         0

# %%
def tokenize(txt):
  if isinstance(txt,list):
    tokens=[t.lower()for t in txt]
  else:
      tokens=re.split('\W+',txt.lower())
  return tokens
